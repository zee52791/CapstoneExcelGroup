# %%
import pandas as pd
import string

# %%
dummy = list(string.ascii_lowercase)[:6]
k = 0
for i in range(2016, 2021):
    year = str(i)
    dummy[k] = pd.read_pickle(f'cpsaat-{year}.pkl')
    k += 1

# %%
pd.concat([dummy[0], dummy[1], dummy[2], dummy[3], dummy[4]], axis=1)
# Out:
#                                                                                              2016  \
#                                                                   Less than a high school diploma
#                                                                   Less than a high school diploma
# TOTAL                        Civilian noninstitutional population                          23,368
#                              Civilian labor force                                          10,679
#                              Participation rate                                              45.7
#                              Employed                                                       9,884
#                              Employment-population ratio                                     42.3
#                              Unemployed                                                       795
# ...
